# %%
import pandas as pd
import numpy as np
from imblearn.combine import SMOTEENN
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
import chardet
import os
# importing the necessary libraries

# %%
data = open('final_telco.csv', 'rb').read()

# %%
chardet.detect(data)['encoding']
# Out:
# 'ascii'

# %%
df = Data_Getter().get_data()

# %%
df.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %%
df.head()
# dataset
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv', encoding='unicode_escape')
df.head()
# reading the dataset
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df=df.drop(['customerID','SeniorCitizen', 'tenure', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'TechSupport', 'StreamingTV', 'StreamingMovies', 
        'PaperlessBilling', 'TotalCharges'], axis=1)
# dropping irrelavent features

# %%
df.head()
# Out:
#    gender Partner Dependents InternetService DeviceProtection        Contract  \
# 0  Female     Yes         No             DSL               No  Month-to-month
# 1    Male      No         No             DSL              Yes        One year
# 2    Male      No         No             DSL               No  Month-to-month
# 3    Male      No         No             DSL              Yes        One year
# 4  Female      No         No     Fiber optic               No  Month-to-month
#
#                PaymentMethod  MonthlyCharges Churn
# 0           Electronic check           29.85    No
# 1               Mailed check           56.95    No
# 2               Mailed check           53.85   Yes
# 3  Bank transfer (automatic)           42.30    No
# 4           Electronic check           70.70   Yes

# %%
str.encode('utf-8').strip()
# Out:
# b'utf-8'

# %%
df.isnull().sum()
# Out:
# gender              0
# Partner             0
# Dependents          0
# InternetService     0
# DeviceProtection    0
# Contract            0
# PaymentMethod       0
# MonthlyCharges      0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   Partner           7043 non-null   object
#  2   Dependents        7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   DeviceProtection  7043 non-null   object
#  5   Contract          7043 non-null   object
#  6   PaymentMethod     7043 non-null   object
#  7   MonthlyCharges    7043 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 495.3+ KB

# %%
df['MonthlyCharges'].unique()
#print the unique values of the 'MonthlyCharges' column
# Out:
# array([29.85, 56.95, 53.85, ..., 63.1 , 44.2 , 78.7 ])

# %%
df['Churn'] = np.where(df.Churn == 'Yes',1,0)
# converts the churn coloumn into a  binary 0 and 1

# %%
df.head()
# Out:
#    gender Partner Dependents InternetService DeviceProtection        Contract  \
# 0  Female     Yes         No             DSL               No  Month-to-month
# 1    Male      No         No             DSL              Yes        One year
# 2    Male      No         No             DSL               No  Month-to-month
# 3    Male      No         No             DSL              Yes        One year
# 4  Female      No         No     Fiber optic               No  Month-to-month
#
#                PaymentMethod  MonthlyCharges  Churn
# 0           Electronic check           29.85      0
# 1               Mailed check           56.95      0
# 2               Mailed check           53.85      1
# 3  Bank transfer (automatic)           42.30      0
# 4           Electronic check           70.70      1

# %%
df_dummies=pd.get_dummies(df)
# creates binary of the coloumns gender	,Partner,	Dependents,	InternetService	DeviceProtection	,Contract,	PaymentMethod

# %%
df_dummies.head()
# Out:
#    MonthlyCharges  Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  \
# 0           29.85      0              1            0           0            1
# 1           56.95      0              0            1           1            0
# 2           53.85      1              0            1           1            0
# 3           42.30      0              0            1           1            0
# 4           70.70      1              1            0           1            0
#
#    Dependents_No  Dependents_Yes  InternetService_DSL  \
# 0              1               0                    1
# 1              1               0                    1
# 2              1               0                    1
# 3              1               0                    1
# 4              1               0                    0
#
#    InternetService_Fiber optic  ...  DeviceProtection_No  \
# 0                            0  ...                    1
# ...

# %%
df_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   MonthlyCharges                           7043 non-null   float64
#  1   Churn                                    7043 non-null   int32
#  2   gender_Female                            7043 non-null   uint8
#  3   gender_Male                              7043 non-null   uint8
#  4   Partner_No                               7043 non-null   uint8
#  5   Partner_Yes                              7043 non-null   uint8
#  6   Dependents_No                            7043 non-null   uint8
#  7   Dependents_Yes                           7043 non-null   uint8
#  8   InternetService_DSL                      7043 non-null   uint8
#  9   InternetService_Fiber optic              7043 non-null   uint8
# ...

# %%
df_dummies.head()
# Out:
#    MonthlyCharges  Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  \
# 0           29.85      0              1            0           0            1
# 1           56.95      0              0            1           1            0
# 2           53.85      1              0            1           1            0
# 3           42.30      0              0            1           1            0
# 4           70.70      1              1            0           1            0
#
#    Dependents_No  Dependents_Yes  InternetService_DSL  \
# 0              1               0                    1
# 1              1               0                    1
# 2              1               0                    1
# 3              1               0                    1
# 4              1               0                    0
#
#    InternetService_Fiber optic  ...  DeviceProtection_No  \
# 0                            0  ...                    1
# ...

# %%
os.getcwd()

# %%
df_dummies.to_csv('"C:\Users\SAHAYA KEWINSTON\OneDrive\Desktop\customer-churn-prediction-main\final_telco.csv"')
# saving the file to the specified path

# %%
df = pd.read_csv('final_telco.csv', encoding='unicode_escape')
df.head()
# Out:
#    Unnamed: 0  MonthlyCharges  Churn  gender_Female  gender_Male  Partner_No  \
# 0           0           29.85      0              1            0           0
# 1           1           56.95      0              0            1           1
# 2           2           53.85      1              0            1           1
# 3           3           42.30      0              0            1           1
# 4           4           70.70      1              1            0           1
#
#    Partner_Yes  Dependents_No  Dependents_Yes  InternetService_DSL  ...  \
# 0            1              1               0                    1  ...
# 1            0              1               0                    1  ...
# 2            0              1               0                    1  ...
# 3            0              1               0                    1  ...
# 4            0              1               0                    0  ...
#
#    DeviceProtection_No  DeviceProtection_No internet service  \
# ...

# %%
df.drop(['Unnamed: 0'], axis=1,inplace = True)
# dropping the coloumn nmaed unnamed

# %%
df.head()
# Out:
#    MonthlyCharges  Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  \
# 0           29.85      0              1            0           0            1
# 1           56.95      0              0            1           1            0
# 2           53.85      1              0            1           1            0
# 3           42.30      0              0            1           1            0
# 4           70.70      1              1            0           1            0
#
#    Dependents_No  Dependents_Yes  InternetService_DSL  \
# 0              1               0                    1
# 1              1               0                    1
# 2              1               0                    1
# 3              1               0                    1
# 4              1               0                    0
#
#    InternetService_Fiber optic  ...  DeviceProtection_No  \
# 0                            0  ...                    1
# ...

# %%
x=df.drop('Churn',axis=1)
x
# Out:
#       MonthlyCharges  gender_Female  gender_Male  Partner_No  Partner_Yes  \
# 0              29.85              1            0           0            1
# 1              56.95              0            1           1            0
# 2              53.85              0            1           1            0
# 3              42.30              0            1           1            0
# 4              70.70              1            0           1            0
# ...              ...            ...          ...         ...          ...
# 7038           84.80              0            1           0            1
# 7039          103.20              1            0           0            1
# 7040           29.60              1            0           0            1
# 7041           74.40              0            1           0            1
# 7042          105.65              0            1           1            0
#
#       Dependents_No  Dependents_Yes  InternetService_DSL  \
# ...

# %%
y=df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# splitting the dataset into trainning and testing dataset

# %% [markdown]
# ## Decision Tree classifier

# %%
model_dt=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)
# model selection 
# here we have used gini index 
# random  state is 100%

# %%
model_dt.fit(x_train,y_train)
# trainning the model
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_dt.predict(x_test)
y_pred
# making the prediction using the trainned model
# Out:
# array([1, 0, 0, ..., 1, 0, 1], dtype=int64)

# %%
model_dt.score(x_test,y_test) 
# prints accuracy  score
# Out:
# 0.7821149751596878

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86      1048
#            1       0.58      0.52      0.55       361
#
#     accuracy                           0.78      1409
#    macro avg       0.71      0.70      0.70      1409
# weighted avg       0.78      0.78      0.78      1409

# %%
sm = SMOTEENN()
# applying synthetic minority oversampling technique 
X_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train,xr_test,yr_train,yr_test=train_test_split(X_resampled, y_resampled,test_size=0.2)

# %%
model_dt_smote=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt_smote.fit(xr_train,yr_train)
yr_predict = model_dt_smote.predict(xr_test)
model_score_r = model_dt_smote.score(xr_test, yr_test)
print(model_score_r)
print(metrics.classification_report(yr_test, yr_predict))
# Out:
# 0.922077922077922
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       552
#            1       0.93      0.93      0.93       603
#
#     accuracy                           0.92      1155
#    macro avg       0.92      0.92      0.92      1155
# weighted avg       0.92      0.92      0.92      1155

# %% [markdown]
# # Saving the model

# %%
import pickle

# %%
filename = 'telco_model.pkl'

# %%
pickle.dump(model_dt_smote, open(filename, 'wb'))

# %%
load_model=pickle.load(open(filename, 'rb'))

# %%
load_model.score(xr_test, yr_test)*100

# enhanced accuracy
# Out:
# 92.20779220779221
